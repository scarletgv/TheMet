# %%
import io
import sqlite3
import pandas as pd
import matplotlib as plt

# %%
artists = pd.read_csv("base/artists.csv") 
objectstable= pd.read_csv("base/objectstable.csv") 
objectstable
# Out:
#         Object ID Object Name                        Department  \
# 0               1        Coin          American Decorative Arts
# 1               2        Coin          American Decorative Arts
# 2               3        Coin          American Decorative Arts
# 3               4        Coin          American Decorative Arts
# 4               5        Coin          American Decorative Arts
# 5               6        Coin          American Decorative Arts
# 6               7        Coin          American Decorative Arts
# 7               8        Coin          American Decorative Arts
# 8               9        Coin          American Decorative Arts
# 9              10        Coin          American Decorative Arts
# 10             11        Coin          American Decorative Arts
# 11             12        Coin          American Decorative Arts
# 12             13        Coin          American Decorative Arts
# 13             14        Coin          American Decorative Arts
# ...
